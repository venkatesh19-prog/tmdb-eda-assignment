# %%
import requests
import pandas as pd
import sqlite3

# %%
url = "https://api.themoviedb.org/3/discover/movie"

params = {
    "api_key": API_KEY,
    "language": "en-US",
    "page": 1
}

response = requests.get(url, params=params)
data = response.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1738/2969966706.py in <cell line: 0>()
#       2
#       3 params = {
# ----> 4     "api_key": API_KEY,
#       5     "language": "en-US",
#       6     "page": 1
#
# NameError: name 'API_KEY' is not defined

# %%
# Import the Python SDK
from google.colab import userdata

API_KEY = userdata.get('API_KEY')

# %%
url = "https://api.themoviedb.org/3/discover/movie"

params = {
    "api_key": API_KEY,
    "language": "en-US",
    "page": 1
}

response = requests.get(url, params=params)
data = response.json()

# %%
if 'results' in data:
    df = pd.DataFrame(data['results'])
    print(df.head())
else:
    print("Error:", data)

# %%
df['genre_ids'] = df['genre_ids'].astype(str)

conn = sqlite3.connect("movies.db")

df.to_sql("movies", conn, if_exists="replace", index=False)

conn.close()

print("Saved to database")

# %%
conn = sqlite3.connect("movies.db")

movies_df = pd.read_sql("SELECT * FROM movies", conn)

conn.close()

movies_df.head()

# %%
if 'results' in data:
    df = pd.DataFrame(data['results'])
    print(df.head())
else:
    print("Error:", data)

# %%
df['genre_ids'] = df['genre_ids'].astype(str)

conn = sqlite3.connect("movies.db")

df.to_sql("movies", conn, if_exists="replace", index=False)

conn.close()

print("Saved to database")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1738/2827504847.py in <cell line: 0>()
# ----> 1 df['genre_ids'] = df['genre_ids'].astype(str)
#       2
#       3 conn = sqlite3.connect("movies.db")
#       4
#       5 df.to_sql("movies", conn, if_exists="replace", index=False)
#
# NameError: name 'df' is not defined

# %%
conn = sqlite3.connect("movies.db")

movies_df = pd.read_sql("SELECT * FROM movies", conn)

conn.close()

movies_df.head()

# %%
movies_df.head()

# %%
movies_df.describe()

# %%
movies_df_exploded = movies_df.explode('genre_ids')

movies_df_exploded['genre_ids'].value_counts()

# %%
movies_df['genre_ids'] = movies_df['genre_ids'].str.strip('[]')
movies_df['genre_ids'] = movies_df['genre_ids'].str.split(',')

movies_df_exploded = movies_df.explode('genre_ids')

movies_df_exploded['genre_ids'].value_counts()

# %%
movies_df.isnull().sum()
